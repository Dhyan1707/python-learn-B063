# %%
print("hiii")
# Out:
# Running cells with 'Python 3.13.7' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/SBMPC.Student/AppData/Local/Microsoft/WindowsApps/python3.13.exe -m pip install ipykernel -U --user --force-reinstall'
